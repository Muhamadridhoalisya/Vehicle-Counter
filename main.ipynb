# %%
from collections import defaultdict
import cv2
import numpy as np
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO(r"Training\runs\detect\train\weights\best.pt")
video_path = r"assets\toll_gate.mp4"
output_path = r"assets\vehicle_count_output.mp4"

# Open the video file
cap = cv2.VideoCapture(video_path)

# Get video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

# Create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# Store the track history
track_history = defaultdict(lambda: [])

## Get video frame rate
# fps = cap.get(cv2.CAP_PROP_FPS)
wait_time = int(1000 / fps)  # Waktu tunggu dalam milidetik antara setiap frame

# Koordinat untuk menggambar garis
coordinates = {
    "points": [
        ((0, 125), (0, 135)),
        ((75, 165), (75, 175)),
        ((140, 180), (140, 190)),
        ((205, 193), (205, 203)),
        ((273, 208), (273, 218)),
        ((340, 222), (340, 232)),
        ((410, 238), (410, 248)),
        ((484, 255), (484, 265)),
        ((562, 273), (562, 283))
    ],
    "gates": [
        ((0, 125), (65, 150)),
        ((65, 150), (140, 180)),
        ((140, 180), (205, 193)),
        ((205, 193), (273, 208)),
        ((273, 208), (340, 222)),
        ((340, 222), (410, 238)),
        ((410, 238), (484, 255)),
        ((484, 255), (562, 273))
    ]
}

# Struktur data untuk menghitung kendaraan
vehicle_counts = [{"BUS": 0, "CAR": 0} for _ in range(8)]
counted_vehicles = set()

def point_in_polygon(x, y, poly):
    n = len(poly)
    inside = False
    p1x, p1y = poly[0]
    for i in range(n + 1):
        p2x, p2y = poly[i % n]
        if y > min(p1y, p2y):
            if y <= max(p1y, p2y):
                if x <= max(p1x, p2x):
                    if p1y != p2y:
                        xinters = (y - p1y) * (p2x - p1x) / (p2y - p1y) + p1x
                    if p1x == p2x or x <= xinters:
                        inside = not inside
        p1x, p1y = p2x, p2y
    return inside

# Loop through the video frames
frame_count = 0
while cap.isOpened():
    # Break the loop if 'q' is pressed
    if cv2.waitKey(wait_time) & 0xFF == ord("q"):
        break
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)

        # Get the boxes and track IDs
        boxes = results[0].boxes.xywh.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()
        classes = results[0].boxes.cls.cpu().tolist()

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Plot the tracks and count vehicles
        for box, track_id, cls in zip(boxes, track_ids, classes):
            x, y, w, h = box
            track = track_history[track_id]
            track.append((float(x), float(y)))  # x, y center point
            if len(track) > 100:
                track.pop(0)

            # Draw the tracking lines
            points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
            cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=5)

            # Check if vehicle crossed any gate
            for i, (gateA, gateB) in enumerate(coordinates["gates"]):
                gate_poly = [gateA, gateB, (gateB[0], gateB[1]+10), (gateA[0], gateA[1]+10)]
                if point_in_polygon(x, y, gate_poly) and (track_id, i) not in counted_vehicles:
                    vehicle_class = "BUS" if cls == 0 else "CAR"
                    vehicle_counts[i][vehicle_class] += 1
                    counted_vehicles.add((track_id, i))

        # Draw lines on annotated frames
        for pointA, pointB in coordinates["points"]:
            cv2.line(annotated_frame, pointA, pointB, color=(0, 0, 255), thickness=4)

        # Draw gates and add names on them
        for i, (gateA, gateB) in enumerate(coordinates["gates"]):
            cv2.line(annotated_frame, gateA, gateB, color=(0, 255, 0), thickness=4)
    
            # Defines the text position for the gate name.
            text_position = ((gateA[0] + gateB[0]) // 2, (gateA[1] + gateB[1]) // 2 - 10)
    
            # Add gate name text above the line
            gate_name = f"Gate {i+1}"
            cv2.putText(annotated_frame, gate_name, text_position, cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)

        # Display vehicle counts
        # Display vehicle counts for gates 1-4 on the left side
        for i in range(4):
            text = f"Gate {i+1}: BUS {vehicle_counts[i]['BUS']}, CAR {vehicle_counts[i]['CAR']}"
            cv2.putText(annotated_frame, text, (10, 30 + i*20), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (191, 0, 255), 2)

        # Display vehicle counts for gates 5-8 on the right side
        for i in range(4, 8):
            text = f"Gate {i+1}: BUS {vehicle_counts[i]['BUS']}, CAR {vehicle_counts[i]['CAR']}"
            text_size = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 2)[0]
            text_x = annotated_frame.shape[1] - text_size[0] - 10
            cv2.putText(annotated_frame, text, (text_x, 30 + (i-4)*20), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (191, 0, 255), 2)

        # Add text at the bottom center
        total_bus = sum(count["BUS"] for count in vehicle_counts)
        total_car = sum(count["CAR"] for count in vehicle_counts)
        total_vehicles = total_bus + total_car

        # Menambahkan tulisan di bagian bawah tengah
        text_bottom = f"BUS = {total_bus} || CAR = {total_car} || TOTAL = {total_vehicles}"
        text_size = cv2.getTextSize(text_bottom, cv2.FONT_HERSHEY_SIMPLEX, 1, 2)[0]
        text_x = (annotated_frame.shape[1] - text_size[0]) // 2
        text_y = annotated_frame.shape[0] - 10

        # Draw text on annotated frames
        cv2.putText(annotated_frame, text_bottom, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0), 2)

        # # Display progress
        # frame_count += 1
        # progress = f"Progress: {frame_count}/{total_frames} frames"
        # cv2.putText(annotated_frame, progress, (10, height - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", annotated_frame)

        # Write the frame to the output video
        out.write(annotated_frame)

    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
out.release()
cv2.destroyAllWindows()

print()
print(f"Video processing completed. Output saved to: {output_path}")

# Print result after video complete
print()
print("Vehicle Detection Results per Gate:")
for i in range(8):
    gate_result = f"Gate {i+1}: BUS {vehicle_counts[i]['BUS']}, CAR {vehicle_counts[i]['CAR']}"
    print(gate_result)

# Print total of transportation
total_bus = sum(count["BUS"] for count in vehicle_counts)
total_car = sum(count["CAR"] for count in vehicle_counts)
total_vehicles = total_bus + total_car
print(f"\nTotal:")
print(f"BUS = {total_bus}, CAR = {total_car}, TOTAL = {total_vehicles}")
# Out:
# 0: 384x640 1 BUS, 1 CAR, 131.7ms
# Speed: 9.8ms preprocess, 131.7ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 92.4ms
# Speed: 3.3ms preprocess, 92.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 83.6ms
# Speed: 0.0ms preprocess, 83.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 69.1ms
# Speed: 2.7ms preprocess, 69.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 75.0ms
# Speed: 0.0ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 69.8ms
# Speed: 3.0ms preprocess, 69.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 82.9ms
# Speed: 2.7ms preprocess, 82.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 82.3ms
# Speed: 2.8ms preprocess, 82.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 78.0ms
# Speed: 2.2ms preprocess, 78.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 73.7ms
# Speed: 2.0ms preprocess, 73.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 80.4ms
# Speed: 1.8ms preprocess, 80.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 75.1ms
# Speed: 2.0ms preprocess, 75.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 83.0ms
# Speed: 2.1ms preprocess, 83.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 90.2ms
# Speed: 3.0ms preprocess, 90.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 91.0ms
# Speed: 3.3ms preprocess, 91.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 93.2ms
# Speed: 2.7ms preprocess, 93.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 76.6ms
# Speed: 1.9ms preprocess, 76.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 71.7ms
# Speed: 0.0ms preprocess, 71.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 81.1ms
# Speed: 0.0ms preprocess, 81.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 87.9ms
# Speed: 0.0ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 92.7ms
# Speed: 2.3ms preprocess, 92.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 84.3ms
# Speed: 1.2ms preprocess, 84.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 83.2ms
# Speed: 1.6ms preprocess, 83.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 84.3ms
# Speed: 0.0ms preprocess, 84.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 84.5ms
# Speed: 0.0ms preprocess, 84.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 100.8ms
# Speed: 0.0ms preprocess, 100.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 84.9ms
# Speed: 2.0ms preprocess, 84.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 87.6ms
# Speed: 2.0ms preprocess, 87.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 108.8ms
# Speed: 0.0ms preprocess, 108.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 86.4ms
# Speed: 2.6ms preprocess, 86.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 78.0ms
# Speed: 0.0ms preprocess, 78.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 144.7ms
# Speed: 2.4ms preprocess, 144.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 81.5ms
# Speed: 0.0ms preprocess, 81.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 112.3ms
# Speed: 0.0ms preprocess, 112.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 117.3ms
# Speed: 2.1ms preprocess, 117.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 90.2ms
# Speed: 0.0ms preprocess, 90.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 140.0ms
# Speed: 2.1ms preprocess, 140.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 102.5ms
# Speed: 1.6ms preprocess, 102.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 108.4ms
# Speed: 3.1ms preprocess, 108.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 119.0ms
# Speed: 15.6ms preprocess, 119.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 89.1ms
# Speed: 2.4ms preprocess, 89.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 69.9ms
# Speed: 2.9ms preprocess, 69.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 88.5ms
# Speed: 0.0ms preprocess, 88.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 93.3ms
# Speed: 0.0ms preprocess, 93.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 86.2ms
# Speed: 2.7ms preprocess, 86.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 95.5ms
# Speed: 0.0ms preprocess, 95.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 91.5ms
# Speed: 0.0ms preprocess, 91.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 95.7ms
# Speed: 2.0ms preprocess, 95.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 88.7ms
# Speed: 0.0ms preprocess, 88.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 90.2ms
# Speed: 0.0ms preprocess, 90.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 201.0ms
# Speed: 4.1ms preprocess, 201.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 166.2ms
# Speed: 0.0ms preprocess, 166.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 254.9ms
# Speed: 5.3ms preprocess, 254.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 175.7ms
# Speed: 1.9ms preprocess, 175.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 180.0ms
# Speed: 4.4ms preprocess, 180.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 180.2ms
# Speed: 3.6ms preprocess, 180.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 180.9ms
# Speed: 5.1ms preprocess, 180.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 168.1ms
# Speed: 3.6ms preprocess, 168.1ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 157.6ms
# Speed: 7.0ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 171.1ms
# Speed: 6.5ms preprocess, 171.1ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 174.0ms
# Speed: 0.0ms preprocess, 174.0ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 164.8ms
# Speed: 6.7ms preprocess, 164.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 177.6ms
# Speed: 5.1ms preprocess, 177.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 171.2ms
# Speed: 1.6ms preprocess, 171.2ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 175.2ms
# Speed: 2.5ms preprocess, 175.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 155.2ms
# Speed: 3.0ms preprocess, 155.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 188.8ms
# Speed: 0.0ms preprocess, 188.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 169.8ms
# Speed: 5.2ms preprocess, 169.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 169.9ms
# Speed: 2.9ms preprocess, 169.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 179.1ms
# Speed: 4.0ms preprocess, 179.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 181.3ms
# Speed: 4.0ms preprocess, 181.3ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 177.4ms
# Speed: 0.0ms preprocess, 177.4ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 153.8ms
# Speed: 5.0ms preprocess, 153.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 170.9ms
# Speed: 3.5ms preprocess, 170.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 166.8ms
# Speed: 5.0ms preprocess, 166.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 173.1ms
# Speed: 6.7ms preprocess, 173.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 181.5ms
# Speed: 4.0ms preprocess, 181.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 184.4ms
# Speed: 3.6ms preprocess, 184.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 177.0ms
# Speed: 5.9ms preprocess, 177.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 154.0ms
# Speed: 6.8ms preprocess, 154.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 CARs, 170.1ms
# Speed: 4.0ms preprocess, 170.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 CARs, 170.4ms
# Speed: 1.0ms preprocess, 170.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 CARs, 168.6ms
# Speed: 2.3ms preprocess, 168.6ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 CARs, 168.5ms
# Speed: 4.4ms preprocess, 168.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 CARs, 174.2ms
# Speed: 6.1ms preprocess, 174.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 CARs, 187.7ms
# Speed: 0.5ms preprocess, 187.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 CARs, 159.5ms
# Speed: 4.5ms preprocess, 159.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 CAR, 164.5ms
# Speed: 2.1ms preprocess, 164.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 CAR, 187.3ms
# Speed: 1.8ms preprocess, 187.3ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 CAR, 200.3ms
# Speed: 5.5ms preprocess, 200.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 CAR, 202.4ms
# Speed: 8.1ms preprocess, 202.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 205.3ms
# Speed: 3.6ms preprocess, 205.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 186.3ms
# Speed: 3.8ms preprocess, 186.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 148.7ms
# Speed: 3.5ms preprocess, 148.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 179.7ms
# Speed: 1.8ms preprocess, 179.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 199.2ms
# Speed: 4.9ms preprocess, 199.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 194.2ms
# Speed: 6.1ms preprocess, 194.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 205.0ms
# Speed: 3.4ms preprocess, 205.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 202.8ms
# Speed: 5.0ms preprocess, 202.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 168.1ms
# Speed: 4.5ms preprocess, 168.1ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 187.1ms
# Speed: 0.0ms preprocess, 187.1ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 197.5ms
# Speed: 4.3ms preprocess, 197.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 203.9ms
# Speed: 5.1ms preprocess, 203.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 189.9ms
# Speed: 7.5ms preprocess, 189.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 166.9ms
# Speed: 6.9ms preprocess, 166.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 183.1ms
# Speed: 6.3ms preprocess, 183.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 153.1ms
# Speed: 5.1ms preprocess, 153.1ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 174.5ms
# Speed: 5.0ms preprocess, 174.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 193.2ms
# Speed: 7.5ms preprocess, 193.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 187.2ms
# Speed: 14.7ms preprocess, 187.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 186.7ms
# Speed: 41.3ms preprocess, 186.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 178.0ms
# Speed: 4.8ms preprocess, 178.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 163.1ms
# Speed: 7.0ms preprocess, 163.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 156.1ms
# Speed: 1.1ms preprocess, 156.1ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 172.3ms
# Speed: 4.0ms preprocess, 172.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 179.8ms
# Speed: 4.8ms preprocess, 179.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 168.4ms
# Speed: 7.3ms preprocess, 168.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 176.7ms
# Speed: 7.7ms preprocess, 176.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 169.6ms
# Speed: 1.5ms preprocess, 169.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 173.7ms
# Speed: 5.3ms preprocess, 173.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 CAR, 159.0ms
# Speed: 1.7ms preprocess, 159.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 CAR, 180.3ms
# Speed: 3.5ms preprocess, 180.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 176.2ms
# Speed: 3.8ms preprocess, 176.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 183.5ms
# Speed: 0.0ms preprocess, 183.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 168.9ms
# Speed: 7.6ms preprocess, 168.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 184.4ms
# Speed: 8.2ms preprocess, 184.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 166.7ms
# Speed: 4.8ms preprocess, 166.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 155.1ms
# Speed: 5.0ms preprocess, 155.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 173.0ms
# Speed: 3.7ms preprocess, 173.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 170.1ms
# Speed: 2.5ms preprocess, 170.1ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 177.8ms
# Speed: 3.9ms preprocess, 177.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 196.6ms
# Speed: 5.4ms preprocess, 196.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 190.0ms
# Speed: 7.2ms preprocess, 190.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 159.9ms
# Speed: 2.8ms preprocess, 159.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 136.2ms
# Speed: 0.0ms preprocess, 136.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 169.7ms
# Speed: 1.1ms preprocess, 169.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 183.1ms
# Speed: 0.0ms preprocess, 183.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 168.9ms
# Speed: 7.0ms preprocess, 168.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 180.4ms
# Speed: 5.5ms preprocess, 180.4ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 1 CAR, 173.2ms
# Speed: 4.1ms preprocess, 173.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 167.4ms
# Speed: 7.7ms preprocess, 167.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 153.1ms
# Speed: 6.6ms preprocess, 153.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 171.7ms
# Speed: 3.2ms preprocess, 171.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 184.9ms
# Speed: 4.0ms preprocess, 184.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 183.2ms
# Speed: 8.2ms preprocess, 183.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 155.0ms
# Speed: 4.8ms preprocess, 155.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 193.8ms
# Speed: 5.5ms preprocess, 193.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 179.4ms
# Speed: 5.5ms preprocess, 179.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 152.3ms
# Speed: 6.1ms preprocess, 152.3ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 180.1ms
# Speed: 3.0ms preprocess, 180.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 177.5ms
# Speed: 5.8ms preprocess, 177.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 178.6ms
# Speed: 4.0ms preprocess, 178.6ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 172.3ms
# Speed: 8.0ms preprocess, 172.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 181.2ms
# Speed: 1.8ms preprocess, 181.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 167.4ms
# Speed: 6.3ms preprocess, 167.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 1 CAR, 158.0ms
# Speed: 1.2ms preprocess, 158.0ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 203.1ms
# Speed: 5.4ms preprocess, 203.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 179.6ms
# Speed: 1.1ms preprocess, 179.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 176.0ms
# Speed: 5.0ms preprocess, 176.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 183.8ms
# Speed: 4.0ms preprocess, 183.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 175.0ms
# Speed: 5.0ms preprocess, 175.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 160.5ms
# Speed: 6.5ms preprocess, 160.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 154.7ms
# Speed: 1.0ms preprocess, 154.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 173.0ms
# Speed: 5.5ms preprocess, 173.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 173.0ms
# Speed: 6.3ms preprocess, 173.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 182.5ms
# Speed: 5.8ms preprocess, 182.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 170.2ms
# Speed: 3.0ms preprocess, 170.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 165.7ms
# Speed: 4.7ms preprocess, 165.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 234.3ms
# Speed: 4.7ms preprocess, 234.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 162.5ms
# Speed: 6.3ms preprocess, 162.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 171.3ms
# Speed: 4.0ms preprocess, 171.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 170.3ms
# Speed: 5.0ms preprocess, 170.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 182.1ms
# Speed: 3.7ms preprocess, 182.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 172.7ms
# Speed: 7.1ms preprocess, 172.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 178.0ms
# Speed: 3.5ms preprocess, 178.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 160.0ms
# Speed: 0.0ms preprocess, 160.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 175.2ms
# Speed: 3.5ms preprocess, 175.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 171.1ms
# Speed: 8.2ms preprocess, 171.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 177.7ms
# Speed: 5.2ms preprocess, 177.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 185.2ms
# Speed: 5.5ms preprocess, 185.2ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 172.2ms
# Speed: 7.0ms preprocess, 172.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 163.5ms
# Speed: 2.0ms preprocess, 163.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 161.4ms
# Speed: 6.0ms preprocess, 161.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 173.3ms
# Speed: 3.5ms preprocess, 173.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 178.9ms
# Speed: 7.6ms preprocess, 178.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 172.0ms
# Speed: 5.2ms preprocess, 172.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 182.9ms
# Speed: 1.5ms preprocess, 182.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 182.3ms
# Speed: 6.7ms preprocess, 182.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 166.6ms
# Speed: 1.5ms preprocess, 166.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 167.6ms
# Speed: 5.9ms preprocess, 167.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 173.5ms
# Speed: 5.5ms preprocess, 173.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 180.0ms
# Speed: 6.1ms preprocess, 180.0ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 186.6ms
# Speed: 3.0ms preprocess, 186.6ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 181.6ms
# Speed: 2.2ms preprocess, 181.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 178.2ms
# Speed: 4.0ms preprocess, 178.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 155.4ms
# Speed: 7.1ms preprocess, 155.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 173.6ms
# Speed: 2.3ms preprocess, 173.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 244.9ms
# Speed: 4.0ms preprocess, 244.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 257.0ms
# Speed: 3.2ms preprocess, 257.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 259.7ms
# Speed: 8.6ms preprocess, 259.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 193.7ms
# Speed: 5.0ms preprocess, 193.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 160.1ms
# Speed: 0.0ms preprocess, 160.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 175.9ms
# Speed: 7.8ms preprocess, 175.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 188.4ms
# Speed: 5.1ms preprocess, 188.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 176.3ms
# Speed: 4.0ms preprocess, 176.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 178.0ms
# Speed: 3.0ms preprocess, 178.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 169.5ms
# Speed: 0.0ms preprocess, 169.5ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 159.6ms
# Speed: 0.9ms preprocess, 159.6ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 159.4ms
# Speed: 6.4ms preprocess, 159.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 171.5ms
# Speed: 1.5ms preprocess, 171.5ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 160.6ms
# Speed: 7.2ms preprocess, 160.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 159.3ms
# Speed: 3.3ms preprocess, 159.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 175.0ms
# Speed: 5.0ms preprocess, 175.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 173.6ms
# Speed: 2.0ms preprocess, 173.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 164.7ms
# Speed: 5.3ms preprocess, 164.7ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 166.2ms
# Speed: 6.0ms preprocess, 166.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 173.2ms
# Speed: 2.0ms preprocess, 173.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 170.9ms
# Speed: 6.1ms preprocess, 170.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 176.2ms
# Speed: 1.0ms preprocess, 176.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 178.5ms
# Speed: 4.0ms preprocess, 178.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 175.1ms
# Speed: 3.8ms preprocess, 175.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 160.8ms
# Speed: 4.2ms preprocess, 160.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 162.9ms
# Speed: 0.0ms preprocess, 162.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 245.4ms
# Speed: 1.5ms preprocess, 245.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 168.7ms
# Speed: 5.1ms preprocess, 168.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 166.1ms
# Speed: 4.3ms preprocess, 166.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 180.3ms
# Speed: 3.2ms preprocess, 180.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 249.1ms
# Speed: 3.5ms preprocess, 249.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 152.5ms
# Speed: 0.0ms preprocess, 152.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 174.3ms
# Speed: 3.0ms preprocess, 174.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 175.5ms
# Speed: 2.5ms preprocess, 175.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 185.1ms
# Speed: 4.9ms preprocess, 185.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 2 CARs, 191.2ms
# Speed: 7.1ms preprocess, 191.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 200.4ms
# Speed: 1.1ms preprocess, 200.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 168.3ms
# Speed: 5.8ms preprocess, 168.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 168.2ms
# Speed: 4.6ms preprocess, 168.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 164.2ms
# Speed: 4.1ms preprocess, 164.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 162.6ms
# Speed: 3.9ms preprocess, 162.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 191.5ms
# Speed: 0.0ms preprocess, 191.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 181.8ms
# Speed: 3.0ms preprocess, 181.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 196.0ms
# Speed: 4.1ms preprocess, 196.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 190.4ms
# Speed: 6.5ms preprocess, 190.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 200.1ms
# Speed: 5.5ms preprocess, 200.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 215.1ms
# Speed: 4.0ms preprocess, 215.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 169.2ms
# Speed: 3.5ms preprocess, 169.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 167.8ms
# Speed: 4.0ms preprocess, 167.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 165.7ms
# Speed: 3.4ms preprocess, 165.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 170.1ms
# Speed: 0.0ms preprocess, 170.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 188.5ms
# Speed: 4.5ms preprocess, 188.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 187.2ms
# Speed: 4.4ms preprocess, 187.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 173.6ms
# Speed: 3.0ms preprocess, 173.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 188.3ms
# Speed: 4.7ms preprocess, 188.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 184.8ms
# Speed: 4.2ms preprocess, 184.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 190.4ms
# Speed: 4.2ms preprocess, 190.4ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 186.6ms
# Speed: 3.8ms preprocess, 186.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 159.9ms
# Speed: 6.5ms preprocess, 159.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 175.1ms
# Speed: 3.0ms preprocess, 175.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 89.8ms
# Speed: 6.0ms preprocess, 89.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 80.1ms
# Speed: 2.5ms preprocess, 80.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 80.3ms
# Speed: 2.2ms preprocess, 80.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 84.0ms
# Speed: 0.0ms preprocess, 84.0ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 84.9ms
# Speed: 2.7ms preprocess, 84.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 97.4ms
# Speed: 0.0ms preprocess, 97.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 76.2ms
# Speed: 3.1ms preprocess, 76.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 78.3ms
# Speed: 1.5ms preprocess, 78.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 79.6ms
# Speed: 2.9ms preprocess, 79.6ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 76.9ms
# Speed: 2.7ms preprocess, 76.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 81.5ms
# Speed: 1.3ms preprocess, 81.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 81.4ms
# Speed: 0.0ms preprocess, 81.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 76.4ms
# Speed: 2.7ms preprocess, 76.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 77.3ms
# Speed: 2.8ms preprocess, 77.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 77.6ms
# Speed: 2.5ms preprocess, 77.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 85.2ms
# Speed: 0.0ms preprocess, 85.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 83.3ms
# Speed: 1.7ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 84.0ms
# Speed: 0.0ms preprocess, 84.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 79.2ms
# Speed: 0.0ms preprocess, 79.2ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 73.5ms
# Speed: 0.0ms preprocess, 73.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 80.1ms
# Speed: 0.0ms preprocess, 80.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 71.1ms
# Speed: 1.3ms preprocess, 71.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 72.5ms
# Speed: 2.5ms preprocess, 72.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 79.9ms
# Speed: 1.5ms preprocess, 79.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 80.1ms
# Speed: 2.0ms preprocess, 80.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 96.1ms
# Speed: 2.9ms preprocess, 96.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 82.7ms
# Speed: 2.3ms preprocess, 82.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 90.1ms
# Speed: 0.0ms preprocess, 90.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 BUSs, 3 CARs, 76.1ms
# Speed: 2.7ms preprocess, 76.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 82.1ms
# Speed: 2.7ms preprocess, 82.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 81.5ms
# Speed: 2.6ms preprocess, 81.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 78.2ms
# Speed: 2.8ms preprocess, 78.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 74.9ms
# Speed: 3.0ms preprocess, 74.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 77.0ms
# Speed: 2.6ms preprocess, 77.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 77.3ms
# Speed: 3.3ms preprocess, 77.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 69.4ms
# Speed: 2.6ms preprocess, 69.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 72.9ms
# Speed: 0.0ms preprocess, 72.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 85.2ms
# Speed: 0.0ms preprocess, 85.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 79.9ms
# Speed: 2.1ms preprocess, 79.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 75.1ms
# Speed: 0.0ms preprocess, 75.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 78.9ms
# Speed: 0.0ms preprocess, 78.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 71.4ms
# Speed: 2.6ms preprocess, 71.4ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 78.1ms
# Speed: 2.2ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 76.2ms
# Speed: 2.8ms preprocess, 76.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 77.0ms
# Speed: 1.9ms preprocess, 77.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 80.1ms
# Speed: 0.0ms preprocess, 80.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 76.6ms
# Speed: 3.0ms preprocess, 76.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 75.8ms
# Speed: 2.7ms preprocess, 75.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 87.5ms
# Speed: 1.4ms preprocess, 87.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 67.5ms
# Speed: 2.7ms preprocess, 67.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 69.8ms
# Speed: 2.5ms preprocess, 69.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 79.8ms
# Speed: 0.0ms preprocess, 79.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 77.5ms
# Speed: 2.2ms preprocess, 77.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 80.3ms
# Speed: 2.0ms preprocess, 80.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 2 CARs, 83.3ms
# Speed: 3.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 76.9ms
# Speed: 2.1ms preprocess, 76.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 79.4ms
# Speed: 0.0ms preprocess, 79.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 78.5ms
# Speed: 3.1ms preprocess, 78.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 79.8ms
# Speed: 0.0ms preprocess, 79.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 75.9ms
# Speed: 3.5ms preprocess, 75.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 82.5ms
# Speed: 0.0ms preprocess, 82.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 78.8ms
# Speed: 2.4ms preprocess, 78.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 74.2ms
# Speed: 0.0ms preprocess, 74.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 70.0ms
# Speed: 0.0ms preprocess, 70.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 77.4ms
# Speed: 2.6ms preprocess, 77.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 80.1ms
# Speed: 0.0ms preprocess, 80.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 78.3ms
# Speed: 1.6ms preprocess, 78.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 BUS, 3 CARs, 87.1ms
# Speed: 2.7ms preprocess, 87.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 75.2ms
# Speed: 3.2ms preprocess, 75.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 81.6ms
# Speed: 2.2ms preprocess, 81.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 77.4ms
# Speed: 3.4ms preprocess, 77.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 84.8ms
# Speed: 1.5ms preprocess, 84.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 78.8ms
# Speed: 3.9ms preprocess, 78.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 84.3ms
# Speed: 0.0ms preprocess, 84.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 70.5ms
# Speed: 2.2ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 94.7ms
# Speed: 0.0ms preprocess, 94.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 66.3ms
# Speed: 0.0ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 80.2ms
# Speed: 2.3ms preprocess, 80.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 89.9ms
# Speed: 2.0ms preprocess, 89.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 91.5ms
# Speed: 3.7ms preprocess, 91.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 96.6ms
# Speed: 2.7ms preprocess, 96.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 83.5ms
# Speed: 2.2ms preprocess, 83.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 82.5ms
# Speed: 2.2ms preprocess, 82.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 76.6ms
# Speed: 3.5ms preprocess, 76.6ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 78.9ms
# Speed: 0.0ms preprocess, 78.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 76.2ms
# Speed: 1.7ms preprocess, 76.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 83.5ms
# Speed: 2.7ms preprocess, 83.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 71.8ms
# Speed: 2.2ms preprocess, 71.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 72.1ms
# Speed: 0.0ms preprocess, 72.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 70.7ms
# Speed: 2.6ms preprocess, 70.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 67.0ms
# Speed: 3.4ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 79.3ms
# Speed: 0.0ms preprocess, 79.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 76.3ms
# Speed: 2.2ms preprocess, 76.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 98.0ms
# Speed: 0.0ms preprocess, 98.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 77.2ms
# Speed: 1.7ms preprocess, 77.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 79.7ms
# Speed: 0.0ms preprocess, 79.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 74.3ms
# Speed: 2.1ms preprocess, 74.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 77.9ms
# Speed: 1.4ms preprocess, 77.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 85.3ms
# Speed: 0.0ms preprocess, 85.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 83.4ms
# Speed: 3.6ms preprocess, 83.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 CARs, 99.4ms
# Speed: 1.5ms preprocess, 99.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# Video processing completed. Output saved to: assets\vehicle_count_output.mp4
#
# Vehicle Detection Results per Gate:
# Gate 1: BUS 1, CAR 0
# Gate 2: BUS 1, CAR 0
# Gate 3: BUS 0, CAR 1
# Gate 4: BUS 0, CAR 2
# Gate 5: BUS 0, CAR 0
# Gate 6: BUS 0, CAR 0
# Gate 7: BUS 1, CAR 6
# Gate 8: BUS 0, CAR 0
#
# Total:
# BUS = 3, CAR = 9, TOTAL = 12
